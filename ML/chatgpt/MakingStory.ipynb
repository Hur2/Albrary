# %% [markdown]
# # 코드 부분

# %%
def questionMaking(age, num, qa_dict):
    type = ""
    world_view = ""
    
    for i in range(num):
        type += f"{i+1}번: ({i+1}번 질문) '+' '(답변 예시)','(답변 예시)','(답변 예시)' \n"
    for key, value in qa_dict.items():
        world_view += f"- {key} {value} \n"
    
    prompt = f'''
당신은 대한민국의 {age}살 동화 작가와 대화하고 있습니다. 
보기의 세계관을 참고하여, 동화 내용에 대한 적절한 질문을 하시오.

질문은 무조건 {num}개만 할 수 있고, 한번에 하나의 질문만 해야합니다.
질문은 동화를 스토리를 위해서 창의성이 있어야 합니다.
질문은 보기와 관련없어도 됩니다.
작가는 {age}살이므로, 질문은 나이 수준을 고려해야 합니다.
반드시 정확한 캐릭터 이름을 사용하시오.

다음의 형식을 따라 질문하세요.
질문 번호가 커질수록, 스토리의 후반부 질문을 하시요.
{type}
보기(세계관):
{world_view}
'''
    print(prompt)
    return prompt
    # 이걸 gpt api로 보내고 받은 결과물을 반환해주면 될듯

# %%
def storyMaking(num, qa_dict):

    type = ""
    world_view = ""
    
    for i in range(num):
        type += f"문단{i+1}: (내용) \n"
    for key, value in qa_dict.items():
        world_view += f"- {key} {value} \n"
    
    prompt = f'''
당신은 대한민국의 최고의 동화 작가입니다.
아래의 세계관을 참고하여서 동화책을 작성하시오.

이야기가 매끄럽게 이어지지 않는다면, 세계관을 추가해도 됩니다.
동화책은 반드시 답변의 형식에 맞게 작성하시오.
한 문단은 3문장 이내입니다. 
한 문단은 반드시 하나의 장면만 묘사하시오.
동화는 구체적이고 창의적으로 써야합니다.
답변은 반드시 동화의 스토리만 다루시오.

세계관:
{world_view}
다음의 형식을 따라 답변하시오.
{type}

'''
    print(prompt)
    return prompt

# %%
def characterMaking(world_view):
    
    prompt = f'''
당신은 이 동화에서 캐릭터를 추출해야 합니다.
스토리를 참고하여, 캐릭터를 일반명사로 쓰시오. 고유명사는 빼고 쓰시오.
캐릭터의 이름이 아닌, 종(species) 이름을 쓰시오.
인간인 경우는 성별을 포함하여 쓰시오.
단수형으로 쓰시오.
캐릭터는 최대 5명까지만 쓰시오.

스토리
{world_view}

다음의 형식을 따라 영어로 답변하세요.
등장인물1: "(영어 일반명사)"
등장인물2: "(영어 일반명사)"
등장인물3: "(영어 일반명사)"
등장인물4: "(영어 일반명사)"
등장인물5: "(영어 일반명사)"

'''
    print(prompt)
    return prompt
    # 이걸 gpt api로 보내고 받은 결과물을 반환해주면 될듯

# %%
def storyToBackground(stories):

    story = ""
    type = ""
    for i in stories:
        story += i+'\n'
    for i in range(len(stories)):
        type += f"문단{i+1}:'(배경 설명)'\n"

    
    
    prompt = f'''
보기의 스토리를 참고하여, 각 문단마다 장소 정보를 추출하시오.
등장 캐릭터을 있는 장소에 대해서 영어로 5단어 이내로 서술하시오.

[스토리]
{story}
아래 형식에 맞게 답변하시오.
{type}
'''
    print(prompt)
    return prompt

# %%
import openai

def openai_api(prompt, model_name):
    openai.api_key = "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" #api key 입력해야 함

    response = openai.ChatCompletion.create(
    model=model_name,
    messages=[
        {"role": "system", "content": prompt}
      ]
    )
    output_text = response["choices"][0]["message"]["content"]
    return output_text

# %% [markdown]
# # main

# %%
## 사용자로부터 답변을 받음
## 아래는 예시용

import time
start = time.time()  # 시작 시간 저장


qa_dict = {
    '주인공의 이름은': "검정 거미 크룬", 
    '이야기가 발생하는 장소는': "자취방의 구석진 곳",
    '이야기의 시작은': "인간이 집을 나간 사이, 자취방에 들어와 집을 짓는다",
    '주인공이 만나는 친구는': "바퀴벌레 폴",
    '주인공이 만나는 어려움은': "집주인에게 잡혀 죽을 위험에 처함",
}
age = 5
question_num = 5



prompt = questionMaking(age, question_num, qa_dict)
response = openai_api(prompt, "gpt-4")
print(response)
response = response.split("\n")

print("time :", time.time() - start)  # 현재시각 - 시작시간 = 실행 시간
# Out:
# 당신은 대한민국의 5살 동화 작가와 대화하고 있습니다.
# 보기의 세계관을 참고하여, 동화 내용에 대한 적절한 질문을 하시오.
#
# 질문은 무조건 5개만 할 수 있고, 한번에 하나의 질문만 해야합니다.
# 질문은 동화를 스토리를 위해서 창의성이 있어야 합니다.
# 질문은 보기와 관련없어도 됩니다.
# 작가는 5살이므로, 질문은 나이 수준을 고려해야 합니다.
# 반드시 정확한 캐릭터 이름을 사용하시오.
#
# 다음의 형식을 따라 질문하세요.
# 질문 번호가 커질수록, 스토리의 후반부 질문을 하시요.
# 1번: (1번 질문) '+' '(답변 예시)','(답변 예시)','(답변 예시)'
# 2번: (2번 질문) '+' '(답변 예시)','(답변 예시)','(답변 예시)'
# 3번: (3번 질문) '+' '(답변 예시)','(답변 예시)','(답변 예시)'
# 4번: (4번 질문) '+' '(답변 예시)','(답변 예시)','(답변 예시)'
# 5번: (5번 질문) '+' '(답변 예시)','(답변 예시)','(답변 예시)'
#
# 보기(세계관):
# - 주인공의 이름은 검정 거미 크룬
# - 이야기가 발생하는 장소는 자취방의 구석진 곳
# - 이야기의 시작은 인간이 집을 나간 사이, 자취방에 들어와 집을 짓는다
# - 주인공이 만나는 친구는 바퀴벌레 폴
# - 주인공이 만나는 어려움은 집주인에게 잡혀 죽을 위험에 처함
#
#
# 1번: 검정 거미 크룬이 자취방에서 집을 지으면서 무슨 재미있는 일이 있었니? '+' '크룬이 화장실에서 미끄러져 코를 다쳤어요.','크룬이 천장을 너무 높게 만들어서 사다리를 올라가다가 넘어졌어요.','크룬이 집을 지을 때마다 새로운 물건을 발견했어요.'
# 2번: 바퀴벌레 폴이 크룬에게 어떤 도움을 줄 수 있었어? '+' '폴이 크룬에게 자취방에서 많이 찾는 곳을 알려줬어요.','폴이 크룬이 집을 지을 수 있는 조용한 장소를 찾아줬어요.','폴이 크룬이 위험에 처했을 때 도와주면서 같이 해결하는 방법을 알려줬어요.'
# ...

# %%
refined_response = [i.split(":")[1:] for i in response if i != ''] ##엔터 구분이 없는 경우 예외처리

#print(refined_response)

QAs = []

for i in refined_response:
    q, a = i[0].split("'+'")
    a = a.split("','")

    temp = [q] + a
    temp = [i.replace("'", "").strip() for i in temp]
    
    QAs.append(temp)

for i in QAs:
    print(i)
# Out:
# ['제이크폴원숭이가 대장 코끼리의 콧구멍을 쑤시게 된 이유가 뭐예요?', '그는 코끼리의 무당치르를 도와줄려고 했어요.', '제이크폴이 장난치다가 실수로 코끼리 코끼리를 만졌어요.', '원숭이인 제이크폴이 코끼리와 친구가 되고 싶어서 코끼리에게 접근했어요.']
# ['제이크폴이 외줄타기 공연에 대해 처음에 어떻게 느꼈어요?', '무서워서 전혀 하고 싶지 않았어요.', '조금 두렵지만 도전하고 싶은 마음이 컸어요.', '외줄타기는 제이크폴이 좋아하는 것 중 하나여서 기대감이 컸어요.']
# ['서커스단을 몰래 구경하던 꼬마아이는 제이크폴에게 어떤 도움을 주었나요?', '꼬마아이는 제이크폴에게 외줄타기를 어떻게 하느냐에 대한 팁을 주었어요.', '꼬마아이는 제이크폴이 두려움을 이기도록 격려해 주었어요.', '꼬마아이는 제이크폴에게 용기를 주는 이야기를 해주었어요.']
# ['제이크폴이 외줄타기 공연을 하기 위해 어떤 준비를 했나요?', '제이크폴은 노도 점프하고, 균형을 유지하는 연습을 했어요.', '제이크폴은 공연 전날 밤 새우가 연습했어요.', '제이크폴은 꼬마아이와 함게 연습했어요.']
# ['이야기가 끝나갈 때 제이크폴은 어떤 변화를 겪었나요?', '제이크폴은 두려움을 이기고, 자신감이 생겼어요.', '제이크폴은 외줄타기를 통해 새로운 능력을 발견했어요.', '제이크폴은 이 사건을 통해 대장 코끼리와 좋은 친구가 되었어요.']

# %%
## 위에 결과물을 복사하고, 답변한 작성해서 보냄

qa_dict = {
    '제이크폴원숭이가 대장 코끼리의 콧구멍을 쑤시게 된 이유가 뭐예요?': '제이크폴이 장난치다가 실수로 코끼리 코끼리를 만졌어요.',
    '제이크폴이 외줄타기 공연에 대해 처음에 어떻게 느꼈어요?': '무서워서 전혀 하고 싶지 않았어요.',
    '서커스단을 몰래 구경하던 꼬마아이는 제이크폴에게 어떤 도움을 주었나요?': '꼬마아이는 제이크폴에게 용기를 주는 이야기를 해주었어요.',
    '제이크폴이 외줄타기 공연을 하기 위해 어떤 준비를 했나요?': '제이크폴은 공연 전날 밤 새우가 연습했어요.',
    '이야기가 끝나갈 때 제이크폴은 어떤 변화를 겪었나요?': '제이크폴은 이 사건을 통해 대장 코끼리와 좋은 친구가 되었어요.',
}


prompt = storyMaking(9, qa_dict)
response2 = openai_api(prompt, "gpt-4")
response2 = response2.split("\n")

print(response2)
# Out:
# 당신은 대한민국의 최고의 동화 작가입니다.
# 아래의 세계관을 참고하여서 동화책을 작성하시오.
#
# 이야기가 매끄럽게 이어지지 않는다면, 세계관을 추가해도 됩니다.
# 동화책은 반드시 답변의 형식에 맞게 작성하시오.
# 한 문단은 3문장 이내입니다.
# 한 문단은 반드시 하나의 장면만 묘사하시오.
# 동화는 구체적이고 창의적으로 써야합니다.
# 답변은 반드시 동화의 스토리만 다루시오.
#
# 세계관:
# - 제이크폴원숭이가 대장 코끼리의 콧구멍을 쑤시게 된 이유가 뭐예요? 제이크폴이 장난치다가 실수로 코끼리 코끼리를 만졌어요.
# - 제이크폴이 외줄타기 공연에 대해 처음에 어떻게 느꼈어요? 무서워서 전혀 하고 싶지 않았어요.
# - 서커스단을 몰래 구경하던 꼬마아이는 제이크폴에게 어떤 도움을 주었나요? 꼬마아이는 제이크폴에게 용기를 주는 이야기를 해주었어요.
# - 제이크폴이 외줄타기 공연을 하기 위해 어떤 준비를 했나요? 제이크폴은 공연 전날 밤 새우가 연습했어요.
# - 이야기가 끝나갈 때 제이크폴은 어떤 변화를 겪었나요? 제이크폴은 이 사건을 통해 대장 코끼리와 좋은 친구가 되었어요.
#
# 다음의 형식을 따라 답변하시오.
# 문단1: (내용)
# 문단2: (내용)
# 문단3: (내용)
# 문단4: (내용)
# 문단5: (내용)
# 문단6: (내용)
# 문단7: (내용)
# 문단8: (내용)
# 문단9: (내용)
#
#
#
# ...

# %%
# print(response2)
for i in response2:
    if i == "":
        continue
    print(i)
# Out:
# 문단1: 한 때엔 찬란하게 불타올랐던 서커스단의 빛나는 별, 제이크폴 원숭이는 어느 날 신나게 장난을 치다가 실수로 대장 코끼리의 코끼리를 찔렀다. 거대한 코끼리는 갑작스런 충격에 울부짖으며 코를 흔들었고, 제이크폴은 공중에 던져져 나아가는 동안 “아이고.. 장난이 과하였구나..”라는 생각이 스쳤다.
# 문단2: 그 일로 제이크폴은 물론 대장 코끼리까지 불편한 상황에 빠졌다. 어리둥절한 제이크폴은 대장 코끼리에게 사과하기로 마음을 먹었다. 그러나 대장 코끼리는 얼굴 한켠으로 제이크폴을 쳐다보며, "당신에게는 공연을 한 번 해보라는 부탁이 있소."라고 제안했다.
# 문단3: 그러나 그 공연은 제이크폴이 가장 두려워하는 외줄타기 공연이었다. 할 수 없이 외줄타기 무대를 확인하러 갔지만, 단지 그 생각만 해도 무서워 벌벌 떨었다. 이 순간을 모두에게 들키면 어떻게되나 싶어 서커스 단이 두려웠다.
# 문단4: 그런데 어린 소녀가 자신을 보며 망설이는 제이크폴에게 "공포는 모조리 던져버려야 해. 그럼 비로소 자유로워질 수 있어."라고 말했다. 순수하고 밝은 눈망울이 제이크폴의 마음을 따뜻하게 달궈주며, 용기를 주는 이야기는 그의 마음속에 힘있게 울려 퍼졌다.
# 문단5: 그녀의 말에 힘이 솟은 제이크폴은 공연 전날 밤새 연습에 몰두했다. 끝없이 반복되는 연습이지만, 그림자처럼 쫓아오는 공포를 이겨내기 위한 필요한 과정이었다. 시간은 점점 흘러, 공연이 시작되는 날이 코 앞으로 다가왔다.
# 문단6: 무릎을 탁 치고, 깊게 숨을 들이마신 제이크폴은 천천히 무대로 올라갔다. 어둠 속으로 흩어져 있는 관객들의 기대에 찬 눈빛들을 피해, 무대의 한 가운데에 선 끝을 바라보았다. 그래도 아직까지는 발을 올리지 못하고 그 자리에 서 있었다.
# 문단7: 그때 자신을 응원하는 그 친숙한 목소리를 들었다. 귀를 기울이니 어린 소녀가 외치는 말을 들을 수 있었다. "너밖에 할 수 없는 거야, 제이크폴! 넌 할 수 있어!" 그 말에 제이크폴이 힘을 싣고 첫 발을 뗐다.
# ...

# %% [markdown]
# ## 캐릭터 생성

# %%
story = ""
for i in response2:
    if i != "":
        story += i.split(":")[-1]

prompt = characterMaking(story)
response3 = openai_api(prompt, "gpt-4")
response3 = response3.split("\n")

print(response3)
# Out:
# 당신은 이 동화에서 캐릭터를 추출해야 합니다.
# 스토리를 참고하여, 캐릭터를 일반명사로 쓰시오. 고유명사는 빼고 쓰시오.
# 캐릭터의 이름이 아닌, 종(species) 이름을 쓰시오.
# 인간인 경우는 성별을 포함하여 쓰시오.
# 단수형으로 쓰시오.
# 캐릭터는 최대 5명까지만 쓰시오.
#
# 스토리
# ...

# %%
char = []
for i in response3:
    char.append(i.split(":")[-1].replace('"', '').strip())
print(char)
# Out:
# ['monkey', 'elephant', 'young girl']

# %%
import json
import requests
import io
import base64
from PIL import Image
from rembg import remove


url = ""

for i in char:
    payload = {
        "prompt": "1"+i+", simple background, full body",
        "negative_prompt" : "nsfw",
        "sd_model_checkpoint": "anything-v4.5.safetensors [1d1e459f9f]",
        "steps": 20
    }
    
    response = requests.post(url=f'{url}/sdapi/v1/txt2img', json=payload)
    
    r = response.json()
    
    image = Image.open(io.BytesIO(base64.b64decode(r['images'][0])))
    image = remove(image)

    
    name = i.replace(' ', '_')
    image.save('./'+name+'.png')

# %% [markdown]
# ## 배경 생성

# %%
prompt = storyToBackground(response2)
response4 = openai_api(prompt, "gpt-4") #"gpt-3.5-turbo"
response4 = response4.split("\n")
# Out:
# 보기의 스토리를 참고하여, 각 문단마다 장소 정보를 추출하시오.
# 등장 캐릭터을 있는 장소에 대해서 영어로 5단어 이내로 서술하시오.
#
# [스토리]
# 문단1: 한 때엔 찬란하게 불타올랐던 서커스단의 빛나는 별, 제이크폴 원숭이는 어느 날 신나게 장난을 치다가 실수로 대장 코끼리의 코끼리를 찔렀다. 거대한 코끼리는 갑작스런 충격에 울부짖으며 코를 흔들었고, 제이크폴은 공중에 던져져 나아가는 동안 “아이고.. 장난이 과하였구나..”라는 생각이 스쳤다.
# 문단2: 그 일로 제이크폴은 물론 대장 코끼리까지 불편한 상황에 빠졌다. 어리둥절한 제이크폴은 대장 코끼리에게 사과하기로 마음을 먹었다. 그러나 대장 코끼리는 얼굴 한켠으로 제이크폴을 쳐다보며, "당신에게는 공연을 한 번 해보라는 부탁이 있소."라고 제안했다.
# 문단3: 그러나 그 공연은 제이크폴이 가장 두려워하는 외줄타기 공연이었다. 할 수 없이 외줄타기 무대를 확인하러 갔지만, 단지 그 생각만 해도 무서워 벌벌 떨었다. 이 순간을 모두에게 들키면 어떻게되나 싶어 서커스 단이 두려웠다.
# 문단4: 그런데 어린 소녀가 자신을 보며 망설이는 제이크폴에게 "공포는 모조리 던져버려야 해. 그럼 비로소 자유로워질 수 있어."라고 말했다. 순수하고 밝은 눈망울이 제이크폴의 마음을 따뜻하게 달궈주며, 용기를 주는 이야기는 그의 마음속에 힘있게 울려 퍼졌다.
# 문단5: 그녀의 말에 힘이 솟은 제이크폴은 공연 전날 밤새 연습에 몰두했다. 끝없이 반복되는 연습이지만, 그림자처럼 쫓아오는 공포를 이겨내기 위한 필요한 과정이었다. 시간은 점점 흘러, 공연이 시작되는 날이 코 앞으로 다가왔다.
# 문단6: 무릎을 탁 치고, 깊게 숨을 들이마신 제이크폴은 천천히 무대로 올라갔다. 어둠 속으로 흩어져 있는 관객들의 기대에 찬 눈빛들을 피해, 무대의 한 가운데에 선 끝을 바라보았다. 그래도 아직까지는 발을 올리지 못하고 그 자리에 서 있었다.
# ...

# %%
bg_prompt = []
for i in response4:
    bg_prompt.append(i.split(':')[-1].replace("'","").strip())
bg_prompt
# Out:
# ['Circus performance area',
#  'Elephants living area',
#  'Tightropes performing stage',
#  'Near the performance area',
#  'Rehearsal stage at night',
#  'On the performance stage',
#  'At the circus stage',
#  'Circus with cheering crowd',
#  'At the circus troupe']

# %%
import json
import requests
import io
import base64
from PIL import Image
from rembg import remove

with open('/Users/ojaehwan/Downloads/back_depth.jpeg', 'rb') as img:
    base64_string = base64.b64encode(img.read()).decode()

url = ""
num = 0
for prompt in bg_prompt:
    payload = {
        "prompt": f"{prompt}, background, (masterpiece, best quality), no humans",
        "negative_prompt" : "person, 1girl, boy, woman, man, solo, character, humans, animals",
        "sd_model_checkpoint": "anything-v4.5.safetensors [1d1e459f9f]",
        "steps": 20,
        "width": 512,
        "height": 512,
        "alwayson_scripts": {
            "controlnet": {
              "args": [
                  {
                      "input_image": base64_string,
                      "module" : "depth_midas",
                      "model"  : "control_v11f1p_sd15_depth [cfd03158]",
                      "weight" : 0.5,
                  }
                ]
            }
        }
    }
    response = requests.post(url=f'{url}/sdapi/v1/txt2img', json=payload)
    r = response.json()
    
    image = Image.open(io.BytesIO(base64.b64decode(r['images'][0])))
    image.save(f'./background_{str(num)}.png')
    num+=1

# %%
    '제이크폴원숭이가 대장 코끼리의 콧구멍을 쑤시게 된 이유가 뭐예요?': '제이크폴이 장난치다가 실수로 코끼리 코끼리를 만졌어요.',
    '제이크폴이 외줄타기 공연에 대해 처음에 어떻게 느꼈어요?': '무서워서 전혀 하고 싶지 않았어요.',
    '서커스단을 몰래 구경하던 꼬마아이는 제이크폴에게 어떤 도움을 주었나요?': '꼬마아이는 제이크폴에게 용기를 주는 이야기를 해주었어요.',
    '제이크폴이 외줄타기 공연을 하기 위해 어떤 준비를 했나요?': '제이크폴은 공연 전날 밤 새우가 연습했어요.',
    '이야기가 끝나갈 때 제이크폴은 어떤 변화를 겪었나요?': '제이크폴은 이 사건을 통해 대장 코끼리와 좋은 친구가 되었어요.',


문단1: 한 때엔 찬란하게 불타올랐던 서커스단의 빛나는 별, 제이크폴 원숭이는 어느 날 신나게 장난을 치다가 실수로 대장 코끼리의 코끼리를 찔렀다. 거대한 코끼리는 갑작스런 충격에 울부짖으며 코를 흔들었고, 제이크폴은 공중에 던져져 나아가는 동안 “아이고.. 장난이 과하였구나..”라는 생각이 스쳤다.
문단2: 그 일로 제이크폴은 물론 대장 코끼리까지 불편한 상황에 빠졌다. 어리둥절한 제이크폴은 대장 코끼리에게 사과하기로 마음을 먹었다. 그러나 대장 코끼리는 얼굴 한켠으로 제이크폴을 쳐다보며, "당신에게는 공연을 한 번 해보라는 부탁이 있소."라고 제안했다.
문단3: 그러나 그 공연은 제이크폴이 가장 두려워하는 외줄타기 공연이었다. 할 수 없이 외줄타기 무대를 확인하러 갔지만, 단지 그 생각만 해도 무서워 벌벌 떨었다. 이 순간을 모두에게 들키면 어떻게되나 싶어 서커스 단이 두려웠다.
문단4: 그런데 어린 소녀가 자신을 보며 망설이는 제이크폴에게 "공포는 모조리 던져버려야 해. 그럼 비로소 자유로워질 수 있어."라고 말했다. 순수하고 밝은 눈망울이 제이크폴의 마음을 따뜻하게 달궈주며, 용기를 주는 이야기는 그의 마음속에 힘있게 울려 퍼졌다.
문단5: 그녀의 말에 힘이 솟은 제이크폴은 공연 전날 밤새 연습에 몰두했다. 끝없이 반복되는 연습이지만, 그림자처럼 쫓아오는 공포를 이겨내기 위한 필요한 과정이었다. 시간은 점점 흘러, 공연이 시작되는 날이 코 앞으로 다가왔다.
문단6: 무릎을 탁 치고, 깊게 숨을 들이마신 제이크폴은 천천히 무대로 올라갔다. 어둠 속으로 흩어져 있는 관객들의 기대에 찬 눈빛들을 피해, 무대의 한 가운데에 선 끝을 바라보았다. 그래도 아직까지는 발을 올리지 못하고 그 자리에 서 있었다.
문단7: 그때 자신을 응원하는 그 친숙한 목소리를 들었다. 귀를 기울이니 어린 소녀가 외치는 말을 들을 수 있었다. "너밖에 할 수 없는 거야, 제이크폴! 넌 할 수 있어!" 그 말에 제이크폴이 힘을 싣고 첫 발을 뗐다.
문단8: 광경에 대장 코끼리는 눈물을 흘렸다. 코끼리는 자신이 원했던 것이 제이크폴의 두려움을 극복하는 것이었다는 걸 깨달았다. 서커스 단이 모두 박수를 쳐주며 환호하자, 미소짓는 코끼리의 모습이 한참을 남아서 머무르면서 모두가 따뜻한 미소를 짓게 되었다.
문단9: 그 후로 제이크폴과 대장 코끼리는 친구가 되었다. 한 번의 실수로 초조하게 된 상황에서도 서로 이해하며 용기를 주어, 더 좋은 친구가 되었다. 그렇게 제이크폴은 대장 코끼리의 특별한 친구가 되었으며, 그들의 이야기는 앞으로도 서커스단의 전설로 기억될 것이다.

}

# %%
from flask import Flask, request, jsonify
import subprocess

app = Flask(__name)

@app.route('/run-script', methods=['POST'])
def run_script():
    script = request.json.get('script')  # 클라이언트에서 스크립트를 전송
    try:
        result = subprocess.check_output(['python', '-c', script], universal_newlines=True)
        return jsonify({'output': result})
    except Exception as e:
        return jsonify({'error': str(e)})

if __name__ == '__main__':
    app.run(debug=True)

# %%
{
  "questionData": [
    {
      "question": "주인공 강아지 똥은 왜 시골길 담벼락 아래에서 이야기를 시작하게 되었을까요?",
    },
    {
      "question": "왜 참새와 흙덩이는 강아지 똥에게 하찮은 존재로 생각하고 비하할까요?",
    },
    {
      "question": "주인공 강아지 똥이 만나게 되는 민들레꽃은 어떤 특별한 능력이 있을까요?",
    },
    {
      "question": "참새와 흙덩이를 만난 후에 강아지 똥은 어떤 변화를 겪을까요?",
    },
    {
      "question": "마지막에 강아지 똥의 모습은 어떻게 될까요?",
    }
  ]
}

# %%
{
  "question": "주인공 강아지 똥은 왜 시골길 담벼락 아래에서 이야기를 시작하게 되었을까요?",
  "options": [
    "그 곳에 숨겨진 보물이 있어서",
    "우연히 그곳에 강아지 똥이 떨어져서",
    "다른 동물들과 만나기 위해서"
  ]
}

# %%
#print(QAs)

r_format = {
  "questionData": []
}

for i in QAs:
    temp = {
      "question": i[0],
      "options": i[1]
    }
    r_format["questionData"].append(temp)


for i in r_format["questionData"]:
    question = i['question']
    options = i['options']
    print(question, options)
# Out:
# 제이크폴원숭이가 대장 코끼리의 콧구멍을 쑤시게 된 이유가 뭐예요? 그는 코끼리의 무당치르를 도와줄려고 했어요.
# 제이크폴이 외줄타기 공연에 대해 처음에 어떻게 느꼈어요? 무서워서 전혀 하고 싶지 않았어요.
# 서커스단을 몰래 구경하던 꼬마아이는 제이크폴에게 어떤 도움을 주었나요? 꼬마아이는 제이크폴에게 외줄타기를 어떻게 하느냐에 대한 팁을 주었어요.
# 제이크폴이 외줄타기 공연을 하기 위해 어떤 준비를 했나요? 제이크폴은 노도 점프하고, 균형을 유지하는 연습을 했어요.
# 이야기가 끝나갈 때 제이크폴은 어떤 변화를 겪었나요? 제이크폴은 두려움을 이기고, 자신감이 생겼어요.

# %%
조교님 질문 있습니다.
데모를 빌드를 해서 제출할 필요는 없나요?
데모 관련해서 제출할게 있는지 질문드립니다!
# Out:
#   Cell In[369], line 1
#     조교님 질문 있습니다.
#         ^
# SyntaxError: invalid syntax

# %%
@app.route('/storyMaking', methods=['POST'])
def storyMaking():
	# 스프링에서 넘어온 json 데이터를 변수에 저장합니다.
    dto_json = request.get_json() 

    qa_dict = {}

    for i in dto_json["questionData"]:
        question = i['question']
        options = i['options']
        qa_dict[question] = options

    prompt = storyMaking(9, qa_dict)
    response = openai_api(prompt, "gpt-4")
    response = response.split("\n")
    refined_response = [i for i in response if i != '']

    r_format = {
        "contents": []
    }
    for i in range(len(refined_response)):
        temp = {}
        temp["page"] = i
        temp["text"] = refined_response[i]
        r_format["contents"].append(temp)

    return r_format


[{"question":"주인공의 이름은?","answer":"오재환"},{"question":"주인공의 성별은?","answer":"여성"},{"question":"주인공의 나이는?","answer":"91"},{"question":"주인공이 가장 좋아하는 것은?","answer":"카트"},{"question":"주인공이 가장 싫어하는 것은?","answer":"학교"}]

# %%
q = [{"question":"주인공의 이름은?","answer":"오재환"},
 {"question":"주인공의 성별은?","answer":"여성"},
 {"question":"주인공의 나이는?","answer":"91"},
 {"question":"주인공이 가장 좋아하는 것은?","answer":"카트"},
 {"question":"주인공이 가장 싫어하는 것은?","answer":"학교"}]


for i in q: 
    a = i["question"]
    b = i["answer"]
